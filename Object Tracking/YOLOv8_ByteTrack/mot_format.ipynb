# %% [markdown]
# ##### Convert Dataset Annotations in MOT challenge format

# %%
import os
import xml.etree.ElementTree as ET

def convert_annotations(xml_folder, output_file):
    with open(output_file, 'w') as f_out:
        
        li = os.listdir(xml_folder)
        li = [int(e[:-4]) for e in li]
        li.sort()
        li = [str(e)+'.xml' for e in li][:1000]
        frame = 1
        for filename in li:
            if filename.endswith('.xml'):
                tree = ET.parse(os.path.join(xml_folder, filename))
                root = tree.getroot()

                for obj in root.findall('object'):
                    class_name = obj.find('class').text
                    class_id = class_mapping.get(class_name, -1)
                    if class_id == -1:
                        continue
                    
                    xmin = int(obj.find('bndbox/xmin').text)
                    ymin = int(obj.find('bndbox/ymin').text)
                    xmax = int(obj.find('bndbox/xmax').text)
                    ymax = int(obj.find('bndbox/ymax').text)

                    # Convert to MOT16 format
                    
                    obj_id = int(obj.find('ID').text)
                    bb_left = xmin
                    bb_top = ymin
                    bb_width = xmax - xmin
                    bb_height = ymax - ymin
                    confidence = 1  # Assuming confidence is always 1
                    x, y, z = -1, -1, -1  # Set world coordinates to -1

                    # Write the MOT16 formatted annotation to output file
                    f_out.write(f"{frame},{obj_id},{bb_left},{bb_top},{bb_width},{bb_height},{confidence},{x},{y},{z}\n")
                frame += 1

# Define class mapping (replace with your own)
class_mapping = {'car': 0, 'motorbike': 1, 'van': 2, 'truck': 3, 'big-truck': 4, 'bus': 5}

# Specify the folder containing XML annotations and the output file
xml_folder = '../Data/GRAM/GRAM-RTMv4/Annotations/M-30/xml/'
output_file = './GRAM_MOT1/M-30.txt'

# Convert annotations
convert_annotations(xml_folder, output_file)

# Specify the folder containing XML annotations and the output file
xml_folder = '../Data/GRAM/GRAM-RTMv4/Annotations/M-30-HD/xml/'
output_file = './GRAM_MOT1/M-30-HD.txt'

# Convert annotations
convert_annotations(xml_folder, output_file)


# Specify the folder containing XML annotations and the output file
xml_folder = '../Data/GRAM/GRAM-RTMv4/Annotations/Urban1/xml/'
output_file = './GRAM_MOT1/Urban1.txt'

# Convert annotations
convert_annotations(xml_folder, output_file)

# %% [markdown]
# #### Perform Tracking on a video and save video after that

# %%
from ultralytics import YOLO


model = YOLO('./runs/detect/yolov8n_gram/weights/best.pt')  # Load a trained model


# Perform tracking with the model
results = model.track(source="./videos/M-30.mp4", tracker = 'bytetrack.yaml', save=True)  # Tracking with ByteTracker
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/M-30.mp4: 768x1280 3 cars, 1 motorbike, 189.1ms
# video 1/1 (2/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/M-30.mp4: 768x1280 3 cars, 1 motorbike, 47.5ms
# video 1/1 (3/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/M-30.mp4: 768x1280 3 cars, 1 motorbike, 24.2ms
# ...

# %%
from ultralytics import YOLO


model = YOLO('./runs/detect/yolov8n_gram/weights/best.pt')  # Load a trained model


# Perform tracking with the model
results = model.track(source="./videos/M-30-HD.mp4", tracker = 'bytetrack.yaml', save=True)  # Tracking with ByteTracker
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/M-30-HD.mp4: 768x1280 1 car, 21.7ms
# video 1/1 (2/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/M-30-HD.mp4: 768x1280 1 car, 14.0ms
# video 1/1 (3/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/M-30-HD.mp4: 768x1280 1 car, 14.1ms
# ...

# %%
from ultralytics import YOLO


model = YOLO('./runs/detect/yolov8n_gram/weights/best.pt')  # Load a trained model


# Perform tracking with the model
results = model.track(source="./videos/Urban1.mp4", tracker = 'bytetrack.yaml', save=True)  # Tracking with ByteTracker
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/Urban1.mp4: 768x1280 2 cars, 32.5ms
# video 1/1 (2/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/Urban1.mp4: 768x1280 2 cars, 26.0ms
# video 1/1 (3/1000) /data/home/anujkumar1/DeepTraffic/Object Tracking/YOLOv8_ByteTrack/videos/Urban1.mp4: 768x1280 2 cars, 14.7ms
# ...

# %% [markdown]
# ### Convert Video into Frames

# %%
import cv2
import os

def video_to_frames(video_path, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    video_capture = cv2.VideoCapture(video_path)
    total_frames = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in the video: {total_frames}")

    frame_count = 0

    # Loop through each frame in the video
    while True:
        success, frame = video_capture.read()
        if not success:
            break

        # Save the frame as an image file
        frame_filename = f"frame_{frame_count:05d}.jpg"
        frame_path = os.path.join(output_folder, frame_filename)
        cv2.imwrite(frame_path, frame)

        frame_count += 1

    video_capture.release()
    print(f"Frames extracted and saved to {output_folder}")

# Example usage:
video_path = "./runs/detect/track/M-30-HD.avi"
output_folder = "./runs/detect/frame/M-30-HD/"
video_to_frames(video_path, output_folder)
# Out:
# Total frames in the video: 1000
# Frames extracted and saved to ./runs/detect/frame/M-30-HD/
